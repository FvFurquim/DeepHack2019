# %%
from zipfile import ZipFile
from io import BytesIO
from urllib.request import urlopen
import pandas as pd
endereco = "https://transparencia.tce.sp.gov.br/iegm-deephack2019"
arquivo = urlopen(endereco)
zipfile = ZipFile(BytesIO(arquivo.read())) 
df = pandas.read_csv(zipfile.open('iegm.csv'),encoding='latin-1',error_bad_lines = False, sep=';')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from google.colab import files
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#   cod_ibge  ...                                 valor_resposta
# 0  3500204  ...  instrumento normativo publicado ou promulgado
# 1  3501202  ...             está em outras fases de elaboração
# 2  3500303  ...                           não realizou o plano
# 3  3500402  ...  instrumento normativo publicado ou promulgado
# 4  3500501  ...             está em outras fases de elaboração
#
# [5 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['cod_ibge', 'municipio', 'porte', 'ano_exercicio', 'indice',
#        'cod_pergunta', 'texto_pergunta_genérica', 'cod_resposta',
#        'rotulo_resposta', 'valor_resposta'],
#       dtype='object')

# %%
ambDF = df.loc[df['indice'] == 'i-Amb']
ambDF = df.drop(columns=['cod_ibge', 'municipio', 'porte', 'ano_exercicio', 'indice'])
ambDF['rotulo_resposta'].value_counts()
# Out:
# possuem                                                                                  75164
# não possuem                                                                              63121
# pré-escola                                                                               32750
# creche                                                                                   32750
# realizam                                                                                 24903
# anos iniciais                                                                            21802
# realizaram                                                                               14623
# percentual                                                                                9636
# outros motivos                                                                            8084
# não realizam                                                                              8036
# ...

# %%
 pd.options.display.max_rows = 200
 pd.options.display.max_colwidth = 300

ambDF['texto_pergunta_genérica'].value_counts()
# Out:
# Qual a quantidade de médicos ativos do município em Dezembro?                                                                                                                                                                                                                                                                                                                                      50232
# Sobre as internações clínicas de pacientes residentes no município ocorridas, informe: total de internações clínicas                                                                                                                                                                                                                                                                               36064
# ...

# %%
ambDF['valor_resposta'].value_counts()
# Out:
# Sim                                                                                                                                                                                                                                                                                                                                                                                                                                                        154303
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                          132775
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
despesasDF = pd.read_json('https://transparencia.tce.sp.gov.br/api/json/despesas/jarinu/2015/1')

# %%
despesasDF.head(15)
# Out:
#    dt_emissao_despesa     evento  ...                       orgao vl_despesa
# 0          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   53500,00
# 1          16/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU     187,00
# 2          13/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU     100,20
# 3          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU    4655,00
# 4          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   21000,00
# 5          23/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU    5016,00
# 6          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU    7440,00
# 7          15/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU     705,50
# 8          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   15420,00
# 9          05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   67200,00
# 10         05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU    7600,00
# ...

# %%
despesasDF.loc[14]
# Out:
# dt_emissao_despesa                                 28/01/2015
# evento                                              Empenhado
# id_fornecedor         CNPJ - PESSOA JURÍDICA - 67057315000146
# mes                                                   Janeiro
# nm_fornecedor                     SUPERMERCADO CATROQUE  LTDA
# nr_empenho                                            47-2015
# orgao                              CÂMARA MUNICIPAL DE JARINU
# vl_despesa                                              77,31
# Name: 14, dtype: object

# %%
(despesasDF.loc[despesasDF.nm_fornecedor.str.contains("CATROQUE")]).head()
# Out:
#    dt_emissao_despesa           evento  ...                       orgao vl_despesa
# 14         28/01/2015        Empenhado  ...  CÂMARA MUNICIPAL DE JARINU      77,31
# 43         28/01/2015        Empenhado  ...  CÂMARA MUNICIPAL DE JARINU      98,29
# 83         28/01/2015  Valor Liquidado  ...  CÂMARA MUNICIPAL DE JARINU      98,29
# 92         28/01/2015  Valor Liquidado  ...  CÂMARA MUNICIPAL DE JARINU      77,31
#
# [4 rows x 8 columns]

# %%
lista = [x for x in despesasDF['nm_fornecedor'] if 'CATROQUE' in x]

# %%
despesasEmpDF = despesasDF.loc[despesasDF.evento.str.contains("Empenhado")]
despesasEmpDF.head()
# Out:
#   dt_emissao_despesa     evento  ...                       orgao vl_despesa
# 0         05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   53500,00
# 1         16/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU     187,00
# 2         13/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU     100,20
# 3         05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU    4655,00
# 4         05/01/2015  Empenhado  ...  CÂMARA MUNICIPAL DE JARINU   21000,00
#
# [5 rows x 8 columns]
